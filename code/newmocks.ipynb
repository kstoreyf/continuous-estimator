# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

import Corrfunc

import utils
import plotter

# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
from matplotlib import pylab
# %config InlineBackend.figure_format = 'retina'
matplotlib.rcParams['figure.dpi'] = 80
textsize = 'x-large'
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (6, 4),
         'axes.labelsize': textsize,
         'axes.titlesize': textsize,
         'xtick.labelsize': textsize,
         'ytick.labelsize': textsize}
pylab.rcParams.update(params)

# %%
#cat_tag = 'test'
cat_tag = 'example'

cat_dir = '../../external/lognormal_galaxies/data/catalog_{}'.format(cat_tag)
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)

# %%
plt.plot(r_true, xi_true, color='k')
plt.xlim(40, 200)
plt.ylim(-0.001, 0.005)
# Out:
# (-0.001, 0.005)

# %%
plt.plot(r_avg, xi)
#plt.xscale('log')
#plt.yscale('log')
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))

# %%
#cat_tag = 'test'
cat_tag = 'N42k'

cat_dir = '../../external/lognormal_galaxies/data/catalog_{}'.format(cat_tag)
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)

# %%
plt.plot(r_avg, xi)
plt.plot(r_true, xi_true, color='k')
#plt.xscale('log')
#plt.yscale('log')
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
# Out:
# (-0.001141094037704904, 0.005304808000201611)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_1mill'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.455

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.00023661462201352013, 0.007250299731774046)

# %%
#cat_tag = 'test'
cat_tag = 'L1000'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.455

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.0008866061038421691, 0.006632589277035361)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_p700'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.455

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.000597634559144633, 0.006973075512589855)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_N300k'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.455

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.000396269833433327, 0.006073968018457387)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_N300k_b1_z0'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.0

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.0003062197170484726, 0.002766091592404818)

# %% [markdown]
# Ah! it goes bad with the same params i was using before!

# %%
#cat_tag = 'test'
cat_tag = 'L750_N125k'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.0

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.0005284205287995336, 0.002809487285983181)

# %% [markdown]
# Not great either even with higher number density

# %%
#cat_tag = 'test'
cat_tag = 'L750_N300k'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.0

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.00015532873597867702, 0.0036377929914532814)

# %% [markdown]
# Ah! worse!

# %%
#cat_tag = 'test'
cat_tag = 'L1000_N125k'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.0

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.0010792360155594816, 0.0027254970364767317)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_N1m'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.0

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-9.016906263881186e-05, 0.0034402174674663666)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_N1m_z13'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.0

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-9.016906263881186e-05, 0.0034402174674663666)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_N1m_b1455'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.455

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.00023661462201352013, 0.007250299731774046)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_N1m_planck'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.0

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-9.016906263881186e-05, 0.0034402174674663666)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_N1m_planck_b1455'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.455

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.00023661462201352013, 0.007250299731774046)

# %%
#cat_tag = 'test'
cat_tag = 'L1000_N1m_planck_b1455_ehu'

cat_dir = '../../external/lognormal_galaxies/data'
result_dir = '../results/results_lognormal_{}'.format(cat_tag)

cf_fn = '{}/cf_lin_{}{}.npy'.format(result_dir, 'standard', cat_tag)
r_avg, xi, label = np.load(cf_fn, allow_pickle=True)

# true
true_fn = '{}/inputs/{}_Rh_xi.txt'.format(cat_dir, cat_tag)
r_true, xi_true = np.loadtxt(true_fn, unpack=True)
b1 = 1.455

plt.plot(r_avg, xi)
plt.plot(r_true, xi_true*b1**2, color='k')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.0006611425202371901, 0.023971810679134675)

# %%
#cat_tag = 'test'
cat_tag = '_L750_N125k'
Nrealizations = 100
cat_dir = '../catalogs'
result_dir = '../results/results_lognormal{}'.format(cat_tag)

xis = []
for Nr in range(Nrealizations):
    cf_fn = '{}/cf_lin_{}{}_rlz{}.npy'.format(result_dir, 'theory', cat_tag, Nr)
    r_avg, xi, label = np.load(cf_fn, allow_pickle=True)
    xis.append(xi)
    
    # true
    true_fn = '{}/inputs/cat{}_Rh_xi.txt'.format(cat_dir, cat_tag)
    r_true, xi_true = np.loadtxt(true_fn, unpack=True)
    b1 = 1.5

    plt.plot(r_avg, xi, color='blue', alpha = 0.1)

xi_avg = np.mean(np.array(xis), axis=0)
plt.plot(r_true, xi_true*b1**2, color='k', lw=2)
plt.plot(r_avg, xi_avg, color='cyan')
#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.0009306633215809823, 0.02825862888020314)

# %%
#cat_tag = 'test'
cat_tag = '_L750_N125k_b1'
Nrealizations = 100
cat_dir = '../catalogs'
result_dir = '../results/results_lognormal{}'.format(cat_tag)

xis = []
for Nr in range(Nrealizations):
    cf_fn = '{}/cf_lin_{}{}_rlz{}.npy'.format(result_dir, 'theory', cat_tag, Nr)
    r_avg, xi, label = np.load(cf_fn, allow_pickle=True)
    xis.append(xi)
    
    # true
    true_fn = '{}/inputs/cat{}_Rh_xi.txt'.format(cat_dir, cat_tag)
    r_true, xi_true = np.loadtxt(true_fn, unpack=True)
    b1 = 1.0

    plt.plot(r_avg, xi, color='blue', alpha = 0.1)

xi_avg = np.mean(np.array(xis), axis=0)
plt.plot(r_true, xi_true*b1**2, color='k', lw=2)
plt.plot(r_avg, xi_avg, color='cyan')

#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.0007611289093379936, 0.01076545659563366)

# %%
#cat_tag = 'test'
cat_tag = '_L750_n1e-4'
Nrealizations = 100
cat_dir = '../catalogs'
result_dir = '../results/results_lognormal{}'.format(cat_tag)

#plt.figure(figsize=(10,8))
xis = []
for Nr in range(Nrealizations):
    cf_fn = '{}/cf_lin_{}{}_rlz{}.npy'.format(result_dir, 'theory', cat_tag, Nr)
    r_avg, xi, label = np.load(cf_fn, allow_pickle=True)
    xis.append(xi)
    
    # true
    true_fn = '{}/inputs/cat{}_Rh_xi.txt'.format(cat_dir, cat_tag)
    r_true, xi_true = np.loadtxt(true_fn, unpack=True)
    b1 = 1.5

    plt.plot(r_avg, xi, color='blue', alpha = 0.1)

xi_avg = np.mean(np.array(xis), axis=0)
plt.plot(r_true, xi_true*b1**2, color='k', lw=2)
plt.plot(r_avg, xi_avg, color='cyan', lw=1.5)


#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.0018294969451252419, 0.027057914559195595)

# %%
#cat_tag = 'test'
cat_tag = '_L750_N125k'
cf_tag = '_nb1000'
Nrealizations = 1
cat_dir = '../catalogs'
result_dir = '../results/results_lognormal{}'.format(cat_tag)

#plt.figure(figsize=(10,8))
xis = []
for Nr in range(Nrealizations):
    cf_fn = '{}/cf_lin_{}{}{}_rlz{}.npy'.format(result_dir, 'theory', cf_tag, cat_tag, Nr)
    r_avg, xi, label = np.load(cf_fn, allow_pickle=True)
    xis.append(xi)
    
    # true
    true_fn = '{}/inputs/cat{}_Rh_xi.txt'.format(cat_dir, cat_tag)
    r_true, xi_true = np.loadtxt(true_fn, unpack=True)
    b1 = 1.5

    plt.plot(r_avg, xi, color='blue', alpha = 0.1)

xi_avg = np.mean(np.array(xis), axis=0)
plt.plot(r_true, xi_true*b1**2, color='k', lw=2)
plt.plot(r_avg, xi_avg, color='cyan', lw=1.5)


#plt.xscale('log')
#plt.yscale('log')
plt.xlim(min(r_avg), max(r_avg))
plt.ylim(min(xi), max(xi))
#plt.xlim(min(r_avg), max(r_avg))
#plt.ylim(min(xi), max(xi))
# Out:
# (-0.0051326680625619625, 0.03612048410265678)
